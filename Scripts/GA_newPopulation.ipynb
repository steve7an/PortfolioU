# %%
import bt2Copy2 as bt2
import random
import numpy as np
# Out:
# [ 20  50 100 150 200]

# %%
new_population = np.array([[['tma', '15', '200', 'M', '-1.0'],
       ['ama', '5', '10', 'EL', '-0.30000000000000016'],
       ['sma', '15', '20', 'M', '-0.7000000000000001'],
       ['ama', '20', '150', 'H', '0.4'],
       ['tpma', '3', '150', 'VL', '-0.6000000000000001'],
       ['tpma', '10', '20', 'H', '0.4'],
       ['tpma', '20', '100', 'VL', '-0.5000000000000001'],
       ['ama', '5', '50', 'H', '0.1'],
       ['tpma', '20', '50', 'M', '0.19999999999999973'],
       ['ama', '10', '20', 'H', '0.4']],
	   [['tpma', '3', '10', 'EH', '0.1'],
       ['tma', '5', '150', 'EH', '0.9'],
       ['tpma', '5', '200', 'EL', '-0.30000000000000016'],
       ['tma', '10', '50', 'H', '0.30000000000000004'],
       ['tma', '15', '20', 'EH', '0.30000000000000004'],
       ['tpma', '3', '20', 'M', '-0.1000000000000002'],
       ['tma', '3', '50', 'EL', '-0.8'],
       ['ama', '15', '150', 'EL', '-0.1000000000000002'],
       ['sma', '20', '100', 'EH', '0.2'],
       ['ama', '20', '200', 'M', '-0.9']],
	   [['tma', '5', '100', 'EL', '-0.8'],
       ['ama', '5', '100', 'L', '-0.7000000000000001'],
       ['tma', '15', '200', 'VL', '-0.1000000000000002'],
       ['tma', '10', '200', 'EL', '-1.0'],
       ['tpma', '10', '50', 'EL', '-0.30000000000000016'],
       ['ama', '20', '100', 'H', '0.5'],
       ['tma', '3', '50', 'L', '-0.20000000000000018'],
       ['ama', '15', '50', 'EL', '-0.8'],
       ['tpma', '10', '100', 'VL', '-0.5000000000000001'],
       ['sma', '20', '150', 'VH', '0.0']],
	   [['ama', '10', '150', 'VL', '-0.30000000000000016'],
       ['tpma', '10', '50', 'EH', '0.6000000000000001'],
       ['sma', '5', '100', 'M', '-0.1000000000000002'],
       ['sma', '5', '10', 'EH', '0.6000000000000001'],
       ['ama', '3', '50', 'M', '-0.30000000000000016'],
       ['sma', '3', '200', 'H', '0.30000000000000004'],
       ['tpma', '20', '150', 'EH', '0.2'],
       ['tpma', '10', '20', 'H', '0.7000000000000001'],
       ['tpma', '20', '50', 'VL', '-1.0'],
       ['ama', '15', '200', 'EL', '-1.0']],
	   [['ama', '5', '200', 'EH', '0.6000000000000001'],
       ['tpma', '10', '20', 'EL', '-0.40000000000000013'],
       ['tma', '3', '150', 'M', '-2.220446049250313e-16'],
       ['ama', '20', '150', 'H', '0.8'],
       ['sma', '15', '20', 'EL', '-0.6000000000000001'],
       ['tpma', '10', '200', 'EL', '-1.0'],
       ['tpma', '15', '200', 'L', '-0.8'],
       ['tma', '10', '150', 'EL', '-0.40000000000000013'],
       ['ama', '10', '150', 'VL', '-0.1000000000000002'],
       ['sma', '5', '50', 'EL', '-0.6000000000000001']],
[['tma', '20', '100', 'VH', '0.30000000000000004'],
       ['ama', '20', '200', 'L', '-0.20000000000000018'],
       ['ama', '15', '150', 'VH', '0.2'],
       ['tma', '5', '50', 'VL', '-0.1000000000000002'],
       ['sma', '15', '150', 'VH', '0.8'],
       ['sma', '20', '200', 'L', '-0.40000000000000013'],
       ['tpma', '3', '150', 'H', '0.8'],
       ['tpma', '15', '150', 'VH', '0.9'],
       ['tpma', '15', '20', 'M', '-0.20000000000000018'],
       ['tma', '15', '100', 'VL', '-0.20000000000000018']], 
[['tpma', '15', '100', 'M', '-0.8'],
       ['ama', '15', '150', 'EH', '0.5'],
       ['tpma', '5', '20', 'VL', '-0.7000000000000001'],
       ['ama', '5', '150', 'M', '-2.220446049250313e-16'],
       ['tpma', '5', '20', 'L', '-0.30000000000000016'],
       ['sma', '15', '200', 'M', '0.49999999999999956'],
       ['tma', '3', '100', 'H', '0.7000000000000001'],
       ['ama', '15', '200', 'VH', '0.7000000000000001'],
       ['tma', '20', '200', 'L', '-0.9'],
       ['tpma', '10', '150', 'EL', '-0.8']],
[['tpma', '10', '100', 'L', '-0.5000000000000001'],
       ['tma', '3', '150', 'EH', '0.2'],
       ['ama', '15', '150', 'VL', '-1.0'],
       ['tma', '10', '20', 'VH', '0.5'],
       ['tpma', '5', '20', 'H', '0.4'],
       ['tpma', '20', '100', 'L', '-0.20000000000000018'],
       ['tma', '20', '50', 'EH', '0.30000000000000004'],
       ['ama', '3', '50', 'M', '-0.8'],
       ['tpma', '5', '150', 'H', '0.7000000000000001'],
       ['sma', '5', '20', 'VL', '-0.8']], 
[['tma', '10', '150', 'M', '0.09999999999999964'],
       ['tma', '15', '200', 'M', '0.3999999999999997'],
       ['tma', '5', '20', 'VH', '0.1'],
       ['tpma', '15', '50', 'M', '0.3999999999999997'],
       ['tma', '3', '100', 'EL', '-1.0'],
       ['sma', '3', '100', 'EL', '-0.1000000000000002'],
       ['ama', '15', '150', 'H', '0.1'],
       ['tpma', '5', '50', 'L', '-0.5000000000000001'],
       ['sma', '20', '200', 'EH', '0.1'],
       ['sma', '3', '10', 'VL', '-0.30000000000000016']], 
[['sma', '20', '50', 'VL', '-0.9'],
       ['tma', '5', '200', 'H', '0.6000000000000001'],
       ['tpma', '5', '10', 'M', '-0.5000000000000001'],
       ['tpma', '20', '200', 'EH', '0.0'],
       ['tpma', '5', '100', 'L', '-0.9'],
       ['tpma', '3', '10', 'M', '-0.6000000000000001'],
       ['tpma', '3', '20', 'M', '0.49999999999999956'],
       ['tma', '20', '100', 'H', '0.1'],
       ['ama', '10', '50', 'VH', '0.2'],
       ['tpma', '15', '100', 'M', '-0.8']],
[['sma', '10', '150', 'M', '-0.40000000000000013'],
       ['tpma', '3', '50', 'EL', '-1.0'],
       ['tpma', '3', '100', 'M', '-0.5000000000000001'],
       ['ama', '5', '10', 'L', '-0.7000000000000001'],
       ['tpma', '20', '50', 'VH', '0.8'],
       ['tpma', '20', '150', 'VL', '-0.6000000000000001'],
       ['tma', '3', '100', 'EH', '0.6000000000000001'],
       ['tma', '15', '100', 'L', '-0.1000000000000002'],
       ['tma', '15', '50', 'VL', '-1.0'],
       ['ama', '5', '50', 'EH', '0.7000000000000001']], 
[['sma', '10', '20', 'M', '0.09999999999999964'],
       ['sma', '20', '50', 'EH', '0.6000000000000001'],
       ['tpma', '3', '150', 'VL', '-0.5000000000000001'],
       ['ama', '10', '150', 'VH', '0.2'],
       ['tpma', '10', '200', 'H', '0.30000000000000004'],
       ['tma', '5', '50', 'M', '-2.220446049250313e-16'],
       ['sma', '10', '20', 'L', '-0.40000000000000013'],
       ['tpma', '10', '150', 'M', '0.8999999999999995'],
       ['tpma', '20', '200', 'VH', '0.5'],
       ['ama', '5', '50', 'EL', '-0.20000000000000018']],
[['tpma', '10', '100', 'EH', '0.30000000000000004'],
       ['sma', '3', '100', 'VL', '-0.5000000000000001'],
       ['sma', '10', '100', 'VH', '0.7000000000000001'],
       ['ama', '5', '100', 'VH', '0.6000000000000001'],
       ['tpma', '15', '150', 'EH', '0.2'],
       ['tma', '5', '10', 'EL', '-0.8'],
       ['tpma', '5', '50', 'VL', '-0.5000000000000001'],
       ['sma', '5', '10', 'VH', '0.0'],
       ['tma', '15', '100', 'EH', '0.1'],
       ['tma', '10', '50', 'VH', '0.8']],
[['tma', '20', '200', 'L', '-0.6000000000000001'],
       ['ama', '10', '100', 'L', '-0.9'],
       ['ama', '3', '10', 'VH', '0.4'],
       ['ama', '10', '200', 'VL', '-0.9'],
       ['tma', '20', '50', 'H', '0.8'],
       ['ama', '10', '150', 'H', '0.6000000000000001'],
       ['ama', '3', '100', 'EH', '0.4'],
       ['tpma', '10', '200', 'EH', '0.1'],
       ['sma', '20', '200', 'VL', '-0.40000000000000013'],
       ['ama', '5', '10', 'EH', '0.5']], 
[['sma', '15', '150', 'VH', '0.6000000000000001'],
       ['tma', '5', '10', 'EH', '0.1'],
       ['tma', '20', '100', 'M', '0.2999999999999998'],
       ['tma', '3', '200', 'H', '0.4'],
       ['ama', '10', '150', 'EL', '-0.40000000000000013'],
       ['ama', '20', '50', 'L', '-0.9'],
       ['tma', '5', '20', 'H', '0.9'],
       ['tma', '5', '10', 'H', '0.8'],
       ['tpma', '5', '200', 'EH', '0.6000000000000001'],
       ['sma', '20', '200', 'EL', '-0.40000000000000013']], 
[['tma', '3', '100', 'VL', '-0.5000000000000001'],
       ['sma', '3', '100', 'EH', '0.7000000000000001'],
       ['sma', '15', '150', 'VL', '-0.5000000000000001'],
       ['tpma', '20', '200', 'EL', '-0.1000000000000002'],
       ['sma', '10', '50', 'VL', '-0.9'],
       ['sma', '5', '10', 'VL', '-1.0'],
       ['ama', '10', '20', 'EH', '0.8'],
       ['sma', '3', '10', 'L', '-0.20000000000000018'],
       ['ama', '5', '100', 'VL', '-0.40000000000000013'],
       ['sma', '3', '200', 'M', '-0.5000000000000001']], 
[['sma', '15', '150', 'EH', '0.30000000000000004'],
       ['ama', '3', '20', 'VL', '-0.30000000000000016'],
       ['tma', '10', '50', 'M', '0.3999999999999997'],
       ['tpma', '3', '20', 'M', '0.6999999999999997'],
       ['tma', '5', '10', 'L', '-0.6000000000000001'],
       ['sma', '5', '10', 'M', '0.49999999999999956'],
       ['tpma', '15', '200', 'L', '-0.40000000000000013'],
       ['tpma', '15', '50', 'VL', '-0.30000000000000016'],
       ['tma', '20', '200', 'EL', '-0.20000000000000018'],
       ['sma', '10', '150', 'VH', '0.9']], 
[['tma', '15', '50', 'EL', '-0.8'],
       ['tpma', '5', '100', 'L', '-0.7000000000000001'],
       ['tpma', '15', '20', 'EL', '-0.8'],
       ['ama', '3', '200', 'H', '0.6000000000000001'],
       ['tma', '20', '150', 'VL', '-0.5000000000000001'],
       ['tma', '5', '150', 'M', '0.2999999999999998'],
       ['tma', '20', '100', 'EH', '0.5'],
       ['sma', '3', '200', 'VH', '0.30000000000000004'],
       ['tma', '5', '200', 'EL', '-0.5000000000000001'],
       ['tma', '10', '20', 'L', '-0.6000000000000001']],
[['tma', '15', '100', 'H', '0.4'],
       ['tma', '20', '50', 'H', '0.9'],
       ['tma', '5', '20', 'H', '0.7000000000000001'],
       ['ama', '10', '20', 'VL', '-0.7000000000000001'],
       ['tma', '5', '20', 'L', '-1.0'],
       ['ama', '3', '50', 'L', '-0.5000000000000001'],
       ['tma', '10', '200', 'VH', '0.6000000000000001'],
       ['tma', '15', '50', 'L', '-0.8'],
       ['tpma', '20', '50', 'EH', '0.9'],
       ['ama', '20', '100', 'H', '0.6000000000000001']],
[['ama', '15', '200', 'VL', '-0.7000000000000001'],
       ['tpma', '3', '50', 'EH', '0.2'],
       ['tpma', '5', '200', 'EH', '0.4'],
       ['tma', '15', '150', 'H', '0.30000000000000004'],
       ['tma', '5', '50', 'EL', '-0.8'],
       ['tpma', '20', '50', 'M', '0.7999999999999996'],
       ['tma', '15', '50', 'EL', '-0.40000000000000013'],
       ['sma', '15', '150', 'EH', '0.2'],
       ['sma', '5', '50', 'L', '-0.6000000000000001'],
       ['sma', '3', '50', 'H', '0.4']]])

# %%
def convert_dict(dictPop):
    dictList= []
    for key, value in dictPop.items():
        aKey = key
        aValue = value
        #temp.append(aKey)
        #temp.append(aValue)
        dictList.append(dictPop[aKey]['individual']) 
        aKey = ""
        aValue = ""
    return dictList

# %%
#import numpy as np
new_population1 = bt2.generateRandomPopulation()
new_population = np.array(convert_dict(new_population1))

# %% [markdown]
# # # GA functions and Solution

# %%
def select_mating_pool():
    offspring = []
    for indx in range(20):
        rate_of_return = 0 
        cmp_ror = 0
        tot_cnt = 0 
        for inner in range(10):
            if len(new_population[indx][inner][4]) > 0:
                rate_of_return=float(new_population[indx][inner][4])+rate_of_return
                tot_cnt = tot_cnt +1

        rate_of_return = rate_of_return/tot_cnt


        #if rate_of_return > cmp_ror:
            #offspring.append(new_population[indx])
        ror = [indx,rate_of_return]
        if len(offspring) == 0:
            offspring.append(ror)
            offspring.append(ror)
        elif ror[1] > offspring[0][1]:
            offspring[0] = ror
        elif offspring[0][1] > ror[1] > offspring[1][1]:
            offspring[1] = ror
        #offspring.append(ror)
        #cmp_ror = rate_of_return
        #print(indx)
        #print(rate_of_return,' Rate of return ')
    #import heapq
    #heapq.nlargest(2,offspring)
    new_population1 = []
    #num_parents = 20
    #new_population1 = numpy.empty((num_parents, pop.shape[1]))
    new_population1 = list(new_population[:int(0.8 * len(new_population))])
    for idx in range(len(offspring)):
        new_population1.append(new_population[offspring[idx][0]])
    new_population1.append(bt2.generateRandomIndividual())
    new_population1.append(bt2.generateRandomIndividual())
    return new_population1

# %%
def crossover_pop(pop):
    parents = pop
    offspring = pop # creating empty list / array -- need to check 
    # The point at which crossover takes place between two parents. Usually it is at the center.
    crossover_point = np.uint8(offspring_size[1]/2)
    for k in range(20):
        parent1_idx = random.randint(0,19)
        parent2_idx = random.randint(0,19)
        offspring[k,0:crossover_point] = parents[parent1_idx,0:crossover_point]
        offspring[k,crossover_point:] = parents[parent2_idx, crossover_point:]
        offspring[k,0:crossover_point] = parents[parent2_idx,0:crossover_point]
        offspring[k,crossover_point:] = parents[parent1_idx, crossover_point:]
    return offspring

# %%
def mutation(offspring_gen):
    offspring = offspring_gen
    for idx in range(offspring.shape[0]):
        for idx_m in range(0,3):
            #parent_idx = random.randint(0,19)
            rule_idx = random.randint(0,9)
            offspring[idx,rule_idx] = bt2.generateRandomRule()
    return offspring

# %%
num_weights = 10  ## One individual contains 10 rules

sol_per_pop = 20  ## 10 individuals makes one population
pop_size = (sol_per_pop,num_weights,5)
offspring_size = pop_size
new_population_gen = select_mating_pool()
new_population_gen = np.array(new_population_gen)
offspring_pop = crossover_pop(new_population_gen)

# %%
final_population = mutation(offspring_pop)

# %%
final_population
# Out:
# array([[['tpma', '3', '150', 'EH', '0.30000000000000004'],
#         ['tpma', '20', '150', 'VL', '-0.7000000000000001'],
#         ['sma', '10', '20', 'H', '0.7000000000000001'],
#         ['tpma', '10', '50', 'L', '-0.40000000000000013'],
#         ['sma', '3', '10', 'L', '-0.30000000000000016'],
#         ['tma', '15', '20', 'M', '-0.40000000000000013'],
#         ['tma', '3', '150', 'VH', '0.30000000000000004'],
#         ['tpma', '5', '100', 'VH', '0.6000000000000001'],
#         ['tma', '10', '200', 'M', '-0.5000000000000001'],
#         ['tma', '5', '100', 'L', '-0.6000000000000001']],
#
#        [['ama', '10', '50', 'EL', '-0.20000000000000018'],
#         ['ama', '20', '100', 'VH', '0.2'],
#         ['ama', '20', '100', 'H', '0.8'],
#         ['tpma', '20', '100', 'H', '0.1'],
#         ['tma', '20', '50', 'L', '-1.0'],
#         ['sma', '3', '20', 'VH', '0.2'],
#         ['tma', '20', '200', 'EL', '-0.8'],
#         ['sma', '15', '200', 'H', '0.5'],
# ...
